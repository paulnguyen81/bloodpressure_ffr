# %%
# %load extract_features.py
import pickle
import numpy as np
import pandas as pd
import time
import os
from feature_utils import *

def picklereader(fpath):
    with open(fpath,'rb') as f:
        content = pd.read_pickle(f)
    return content

def scale(sx):
    """
    scalining
    """
    if sx==480:
        return (50**2)*(256/480)**2
    elif sx == 512:
        return (56.5**2)*(256/512)**2

if __name__=='__main__':
    
    t0 = time.time()
    df = picklereader(os.getcwd()+'/data/df18S_rs.p')
    df['luA'] = df['lu'].apply(lambda x: np.array(x))/df['sx0'].apply(lambda x: scale(x)) #convert lumen pixel counts to sqmm
    df['plA'] = df['pl'].apply(lambda x: np.array(x))/df['sx0'].apply(lambda x: scale(x)) #convert plaque pixel counts to sqmm
    #df['pb'] = [plaqueburden(df.ix[i].luA,df.ix[i].plA) for i in df.index] #plaqueburden by frame
    #df['f_1'] = roi(df,'pb').apply(lambda x:len_pb(x,0.4)) #feature 1
    #df['f_2'] = roi(df,'pb').apply(lambda x:len_pb(x,0.7)) #feature 2
    
    #constant variables
    gap = 300       #combines lesions if number of frames between is less than
    pbth = 0.4      #plaque burden threshold in lesion

    ## SMOOTHING
                                       #runtimewarning
    df['luAc'] = df['luA'].apply(lambda x: np.convolve(x,np.ones((50,))/50,mode='same'))                    #smooth luA
    df['plAc'] = df['plA'].apply(lambda x: np.convolve(x,np.ones((50,))/50,mode='same'))                    #smooth plA
    df['pb'] = df.apply(lambda x: list(plaqueburden(x.luAc,x.plAc)),axis=1) 
    t1 = time.time()
    total = t1-t0
    print('Smoothing - Execution time: ',total,"secs")
    
    ## FEATURE EXTRACTION
    #feature 1-11
    t0 = time.time()
    df['len_PB40'] = df.apply(lambda x: lesion(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['len_PB70'] = df.apply(lambda x: lesion(x.luAc,x.plAc,x.distal,x.OS,0.7,gap),axis=1)
    df['OS_PB40'] = df.apply(lambda x: fromos_pb(x.luAc,x.plAc,x.distal,x.OS,0.4,gap),axis=1)
    df['OS_PB70'] = df.apply(lambda x: fromos_pb(x.luAc,x.plAc,x.distal,x.OS,0.7,gap),axis=1)              
    df['OS_MLA'] = df.apply(lambda x: fromos_mla(x.luAc,x.distal,x.OS),axis=1)                             
    df['MLA'] = df.apply(lambda x: mla(x.luAc,x.distal,x.OS),axis=1)
    df['EEM_MLA'] = df.apply(lambda x: eem_mla(x.luAc,x.plAc,x.distal,x.OS),axis=1)
    df['PB_MLA'] = df.apply(lambda x: pb_mla(x.luAc,x.plAc,x.distal,x.OS),axis=1)
    df['No_PB40'] = df.apply(lambda x: numberofpb(x.pb,pbth,x.distal,x.OS),axis=1)                           #runtimewarning
    df['No_PB70'] = df.apply(lambda x: numberofpb(x.pb,0.7,x.distal,x.OS),axis=1)                           #runtimewarning
    t1 = time.time()
    total = t1-t0
    print('Feature 1-11 - Execution time: ',total,"secs")
    
    #feature 12-20
    t0 = time.time()
    df['No_lumen40_ROI'] = df.apply(lambda x: no_lumen_roi(x.luAc,x.plAc,x.distal,x.OS,4.0,0),axis=1)
    df['No_lumen25_ROI'] = df.apply(lambda x: no_lumen_roi(x.luAc,x.plAc,x.distal,x.OS,2.5,0),axis=1)
    df['No_lumen30_ROI'] = df.apply(lambda x: no_lumen_roi(x.luAc,x.plAc,x.distal,x.OS,3.0,0),axis=1)
    df['Sum_plaque_ROI'] = df.apply(lambda x: sum_plaque_roi(x.luAc,x.plAc,x.distal,x.OS,0),axis=1)
    df['Sum_EEM_ROI'] = df.apply(lambda x: sum_eem_roi(x.luAc,x.plAc,x.distal,x.OS,0),axis=1)
    df['PB_ROI'] = df.apply(lambda x: pb_roi(x.luAc,x.plAc,x.distal,x.OS,0),axis=1)
    df['mean_lumen_ROI'] = df.apply(lambda x: mean_lumen_roi(x.luAc,x.plAc,x.distal,x.OS,0),axis=1)
    df['mean_plaque_ROI'] = df.apply(lambda x: mean_plaque_roi(x.luAc,x.plAc,x.distal,x.OS,0),axis=1)
    df['mean_EEM_ROI'] = df.apply(lambda x: mean_eem_roi(x.luAc,x.plAc,x.distal,x.OS,0),axis=1)
    t1 = time.time()
    total = t1-t0
    print('Feature 12-20 - Execution time: ',total,"secs")
        
    #feature 21-29
    t0 = time.time()
    df['No_lumen40_PB40'] = df.apply(lambda x: no_lumen_roi(x.luAc,x.plAc,x.distal,x.OS,4.0,pbth),axis=1)
    df['No_lumen25_PB40'] = df.apply(lambda x: no_lumen_roi(x.luAc,x.plAc,x.distal,x.OS,2.5,pbth),axis=1)
    df['No_lumen30_PB40'] = df.apply(lambda x: no_lumen_roi(x.luAc,x.plAc,x.distal,x.OS,3.0,pbth),axis=1)
    df['Sum_plaque_PB40'] = df.apply(lambda x: sum_plaque_roi(x.luAc,x.plAc,x.distal,x.OS,pbth),axis=1)
    df['Sum_EEM_PB40'] = df.apply(lambda x: sum_eem_roi(x.luAc,x.plAc,x.distal,x.OS,pbth),axis=1)
    df['PB_PB40'] = df.apply(lambda x: pb_roi(x.luAc,x.plAc,x.distal,x.OS,pbth),axis=1)                     
    df['mean_lumen_PB40'] = df.apply(lambda x: mean_lumen_roi(x.luAc,x.plAc,x.distal,x.OS,pbth),axis=1)
    df['mean_plaque_PB40'] = df.apply(lambda x: mean_plaque_roi(x.luAc,x.plAc,x.distal,x.OS,pbth),axis=1)
    df['mean_EEM_PB40'] = df.apply(lambda x: mean_eem_roi(x.luAc,x.plAc,x.distal,x.OS,pbth),axis=1)
    t1 = time.time()
    total = t1-t0
    print('Feature 21-29 - Execution time: ',total,"secs")

    #feature 30-38
    t0 = time.time()
    df['No_lumen40_PB70'] = df.apply(lambda x: no_lumen_roi(x.luAc,x.plAc,x.distal,x.OS,4.0,0.7),axis=1)
    df['No_lumen25_PB70'] = df.apply(lambda x: no_lumen_roi(x.luAc,x.plAc,x.distal,x.OS,2.5,0.7),axis=1)
    df['No_lumen30_PB70'] = df.apply(lambda x: no_lumen_roi(x.luAc,x.plAc,x.distal,x.OS,3.0,0.7),axis=1)
    df['Sum_plaque_PB70'] = df.apply(lambda x: sum_plaque_roi(x.luAc,x.plAc,x.distal,x.OS,0.7),axis=1)
    df['Sum_EEM_PB70'] = df.apply(lambda x: sum_eem_roi(x.luAc,x.plAc,x.distal,x.OS,0.7),axis=1)
    df['PB_PB70'] = df.apply(lambda x: pb_roi(x.luAc,x.plAc,x.distal,x.OS,0.7),axis=1)                     
    df['mean_lumen_PB70'] = df.apply(lambda x: mean_lumen_roi(x.luAc,x.plAc,x.distal,x.OS,0.7),axis=1)
    df['mean_plaque_PB70'] = df.apply(lambda x: mean_plaque_roi(x.luAc,x.plAc,x.distal,x.OS,0.7),axis=1)
    df['mean_EEM_PB70'] = df.apply(lambda x: mean_eem_roi(x.luAc,x.plAc,x.distal,x.OS,0.7),axis=1)
    t1 = time.time()
    total = t1-t0
    print('Feature 30-38 - Execution time: ',total,"secs")

    #feature 39-47
    t0 = time.time()
    df['No_lumen40_worst'] = df.apply(lambda x: no_lumen_worst(x.luAc,x.distal,x.OS,luth=4.0),axis=1)
    df['No_lumen25_worst'] = df.apply(lambda x: no_lumen_worst(x.luAc,x.distal,x.OS,luth=2.5),axis=1)
    df['Sum_plaque_worst'] = df.apply(lambda x: sum_plaque_worst(x.luAc,x.plAc,x.distal,x.OS),axis=1)
    df['Sum_EEM_worst'] = df.apply(lambda x: sum_eem_worst(x.luAc,x.plAc,x.distal,x.OS),axis=1)
    df['PB_worst'] = df.apply(lambda x: pb_worst(x.luAc,x.plAc,x.distal,x.OS),axis=1)
    df['mean_lumen_worst'] = df.apply(lambda x: mean_lumen_worst(x.luAc,x.distal,x.OS),axis=1)
    df['mean_plaque_worst'] = df.apply(lambda x: mean_plaque_worst(x.luAc,x.plAc,x.distal,x.OS),axis=1)
    df['mean_EEM_worst'] = df.apply(lambda x: mean_eem_worst(x.luAc,x.plAc,x.distal,x.OS),axis=1)
    t1 = time.time()
    total = t1-t0
    print('Feature 39-47 - Execution time: ',total,"secs")

    #feature 49-57
    t0 = time.time()
    df['No_lumen40_prox'] = df.apply(lambda x: no_lumen_prox(x.luAc,x.plAc,x.distal,x.OS,pbth,4.0,gap),axis=1)   #all zeroes
    df['No_lumen25_prox'] = df.apply(lambda x: no_lumen_prox(x.luAc,x.plAc,x.distal,x.OS,pbth,2.5,gap),axis=1)   #all zeroes
    df['No_lumen30_prox'] = df.apply(lambda x: no_lumen_prox(x.luAc,x.plAc,x.distal,x.OS,pbth,3.0,gap),axis=1)   #all zeroes
    df['Sum_plaque_prox'] = df.apply(lambda x: sum_plaque_prox(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['Sum_EEM_prox'] = df.apply(lambda x: sum_eem_prox(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['PB_prox'] = df.apply(lambda x: pb_prox(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['mean_lumen_prox'] = df.apply(lambda x: mean_lumen_prox(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['mean_plaque_prox'] = df.apply(lambda x: mean_plaque_prox(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['mean_EEM_prox'] = df.apply(lambda x: mean_eem_prox(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['max_EEM_prox'] = df.apply(lambda x: max_eem_prox(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    t1 = time.time()
    total = t1-t0
    print('Feature 49-57 - Execution time: ',total,"secs")

    #feature 58-67
    t0 = time.time()
    df['No_lumen40_distal'] = df.apply(lambda x: no_lumen_distal(x.luAc,x.plAc,x.distal,x.OS,pbth,4.0,gap),axis=1)
    df['No_lumen25_distal'] = df.apply(lambda x: no_lumen_distal(x.luAc,x.plAc,x.distal,x.OS,pbth,2.5,gap),axis=1)   #all zeroes
    df['No_lumen30_distal'] = df.apply(lambda x: no_lumen_distal(x.luAc,x.plAc,x.distal,x.OS,pbth,3.0,gap),axis=1)   #all zeroes
    df['Sum_plaque_distal'] = df.apply(lambda x: sum_plaque_distal(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['Sum_EEM_distal'] = df.apply(lambda x: sum_eem_distal(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['PB_distal'] = df.apply(lambda x: pb_distal(x.luAc,x.plAc,x.distal,x.OS,0.4,gap),axis=1)
    df['mean_lumen_distal'] = df.apply(lambda x: mean_lumen_distal(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['mean_plaque_distal'] = df.apply(lambda x: mean_plaque_distal(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['mean_EEM_distal'] = df.apply(lambda x: mean_eem_distal(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['max_EEM_distal'] = df.apply(lambda x: max_eem_distal(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    t1 = time.time()
    total = t1-t0
    print('Feature 58-67 - Execution time: ',total,"secs")
    
    
    #feature 68-77
    t0 = time.time()
    df['No_lumen40_prox5'] = df.apply(lambda x: no_lumen40_prox5(x.luAc,x.plAc,x.distal,x.OS,pbth,4.0,gap),axis=1)   #all zeroes
    df['No_lumen25_prox5'] = df.apply(lambda x: no_lumen40_prox5(x.luAc,x.plAc,x.distal,x.OS,pbth,2.5,gap),axis=1)   #all zeroes
    df['No_lumen30_prox5'] = df.apply(lambda x: no_lumen40_prox5(x.luAc,x.plAc,x.distal,x.OS,pbth,3.0,gap),axis=1)   #all zeroes
    df['Sum_plaque_prox5'] = df.apply(lambda x: sum_plaque_prox5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['Sum_EEM_prox5'] = df.apply(lambda x: sum_eem_prox5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['PB_prox5'] = df.apply(lambda x: pb_prox5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['mean_lumen_prox5'] = df.apply(lambda x: mean_lumen_prox5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['mean_plaque_prox5'] = df.apply(lambda x: mean_plaque_prox5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['mean_EEM_prox5'] = df.apply(lambda x: mean_eem_prox5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['max_EEM_prox5'] = df.apply(lambda x: max_eem_prox5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    t1 = time.time()
    total = t1-t0
    print('Feature 68-77 - Execution time: ',total,"secs")
    
    #feature 78-87
    t0 = time.time()
    df['No_lumen40_dist5'] = df.apply(lambda x: no_lumen40_dist5(x.luAc,x.plAc,x.distal,x.OS,pbth,4.0,gap),axis=1)   #all zeroes
    df['No_lumen25_dist5'] = df.apply(lambda x: no_lumen40_dist5(x.luAc,x.plAc,x.distal,x.OS,pbth,2.5,gap),axis=1)   #all zeroes
    df['No_lumen30_dist5'] = df.apply(lambda x: no_lumen40_dist5(x.luAc,x.plAc,x.distal,x.OS,pbth,3.0,gap),axis=1)   #all zeroes
    df['Sum_plaque_dist5'] = df.apply(lambda x: sum_plaque_dist5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['Sum_EEM_dist5'] = df.apply(lambda x: sum_eem_dist5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['PB_dist5'] = df.apply(lambda x: pb_dist5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['mean_lumen_dist5'] = df.apply(lambda x: mean_lumen_dist5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['mean_plaque_dist5'] = df.apply(lambda x: mean_plaque_dist5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['mean_EEM_dist5'] = df.apply(lambda x: mean_eem_dist5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['max_EEM_dist5'] = df.apply(lambda x: max_eem_dist5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    t1 = time.time()
    total = t1-t0
    print('Feature 78-87 - Execution time: ',total,"secs")

    #feature 88-101
    t0 = time.time()
    df['mean_lumen_aver'] = df.apply(lambda x: mean_lumen_aver(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['mean_EEM_aver'] = df.apply(lambda x: mean_eem_aver(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['area1_stenosis_aver'] = df.apply(lambda x: area1_stenosis_aver(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['area1_stenosis_prox5'] = df.apply(lambda x: area1_stenosis_prox5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['area1_stenosis_dist5'] = df.apply(lambda x: area1_stenosis_dist5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['area2_stenosis_aver'] = df.apply(lambda x: area2_stenosis_aver(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['area2_stenosis_prox5'] = df.apply(lambda x: area2_stenosis_prox5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['area2_stenosis_dist5'] = df.apply(lambda x: area2_stenosis_dist5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['area3_stenosis_aver'] = df.apply(lambda x: area3_stenosis_aver(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['area3_stenosis_prox5'] = df.apply(lambda x: area3_stenosis_prox5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['area3_stenosis_dist5'] = df.apply(lambda x: area3_stenosis_dist5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['area4_stenosis_aver'] = df.apply(lambda x: area4_stenosis_aver(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['area4_stenosis_prox5'] = df.apply(lambda x: area4_stenosis_prox5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['area4_stenosis_dist5'] = df.apply(lambda x: area4_stenosis_prox5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    t1 = time.time()
    total = t1-t0
    print('Feature 88-101 - Execution time: ',total,"secs")

    # 102-112 Not completed

    #feature 113-122
    t0 = time.time()
    df['RI_MLA_ref'] = df.apply(lambda x: ri_mla_ref(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['RI_MLA_prox5'] = df.apply(lambda x: ri_mla_prox5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['RI_worst_ref'] = df.apply(lambda x: ri_worst_ref(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['RI_worst_prox5'] = df.apply(lambda x: ri_worst_prox5(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    df['variance_lumen_worst'] = df.apply(lambda x: variance_lumen_worst(x.luAc,x.distal,x.OS),axis=1)
    df['variance_lumen_PB40'] = df.apply(lambda x: variance_lumen_pb40(x.luAc,x.plAc,x.distal,x.OS,pbth),axis=1)
    df['variance_plaque_worst'] = df.apply(lambda x: variance_plaque_worst(x.luAc,x.plAc,x.distal,x.OS),axis=1)
    df['variance_plaque_PB40'] = df.apply(lambda x: variance_plaque_pb40(x.luAc,x.plAc,x.distal,x.OS,pbth),axis=1)
    df['long_eccentricity_worst'] = df.apply(lambda x: long_eccentricity_worst(x.luAc,x.plAc,x.distal,x.OS),axis=1)
    df['long_eccentricity_PB40'] = df.apply(lambda x: long_eccentricity_pb40(x.luAc,x.plAc,x.distal,x.OS,pbth,gap),axis=1)
    t1 = time.time()
    total = t1-t0
    print('Feature 113-122 - Execution time: ',total,"secs")

    print('Feature extraction complete!!!')
# Out:
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:99: RuntimeWarning: invalid value encountered in true_divide
#   return y/(x + y)
# Smoothing - Execution time:  24.963473081588745 secs
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:109: RuntimeWarning: invalid value encountered in greater
#   index = np.where(plaqueburden(lu,pl) > pbth)[0]
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:252: RuntimeWarning: invalid value encountered in greater
#   index = np.where(roi > pbth)[0]
# Feature 1-11 - Execution time:  7.352540016174316 secs
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:290: RuntimeWarning: invalid value encountered in true_divide
#   pb = y/(x + y)
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:291: RuntimeWarning: invalid value encountered in greater
#   pb2 = np.where(pb > pbth)
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:310: RuntimeWarning: invalid value encountered in true_divide
#   pb = y/(x + y)
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:311: RuntimeWarning: invalid value encountered in greater
#   pb2 = np.where(pb > pbth)
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:329: RuntimeWarning: invalid value encountered in true_divide
#   pb = y/(x + y)
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:330: RuntimeWarning: invalid value encountered in greater
#   pb2 = np.where(pb > pbth)
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:362: RuntimeWarning: invalid value encountered in true_divide
#   pb = y/(x + y)
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:363: RuntimeWarning: invalid value encountered in greater
#   pb2 = np.where(pb > pbth)
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:384: RuntimeWarning: invalid value encountered in true_divide
#   pb = y/(x + y)
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:385: RuntimeWarning: invalid value encountered in greater
#   pb2 = np.where(pb > pbth)
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:405: RuntimeWarning: invalid value encountered in true_divide
#   pb = y/(x + y)
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:406: RuntimeWarning: invalid value encountered in greater
#   pb2 = np.where(pb > pbth)
# Feature 12-20 - Execution time:  4.56938624382019 secs
# Feature 21-29 - Execution time:  3.7393691539764404 secs
# Feature 30-38 - Execution time:  2.2965691089630127 secs
# Feature 39-47 - Execution time:  1.435129165649414 secs
# Feature 49-57 - Execution time:  41.934860706329346 secs
# Feature 58-67 - Execution time:  45.312970876693726 secs
# Feature 68-77 - Execution time:  42.598690032958984 secs
# Feature 78-87 - Execution time:  43.85771989822388 secs
# Feature 88-101 - Execution time:  88.33621764183044 secs
# /Users/paulnguyen/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3146: RuntimeWarning: Degrees of freedom <= 0 for slice
#   **kwargs)
# /Users/paulnguyen/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:105: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /Users/paulnguyen/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:1384: RuntimeWarning: invalid value encountered in true_divide
#   pb = y/(x + y)
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:1385: RuntimeWarning: invalid value encountered in greater
#   pb2 = np.where(pb > pbth)[0]
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:1411: RuntimeWarning: invalid value encountered in true_divide
#   pb = y/(x + y)
# /Users/paulnguyen/Desktop/Regis/Practicum2/bloodpressure_ffr/feature_utils.py:1412: RuntimeWarning: invalid value encountered in greater
#   pb2 = np.where(pb > pbth)[0]
# Feature 113-122 - Execution time:  30.62397789955139 secs
# Feature extraction complete!!!

# %%
#removed corrupted records
df = df[df.PID != 'F0871']
df = df[df.PID != 'F1481']

# %%
df.shape

# %%
#Save extracted data to file
#with open('data/df18S_rs_extract.p',"wb") as f:
#    pickle.dump(df, f)

# %%
df = picklereader(os.getcwd()+'/data/df18S_rs_extract.p')

# %%
pd.options.display.max_columns = None
df.describe()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.hist(df['ffr'],bins=20)

# %%
plt.hist(df['age'],bins=20)

# %%
plt.hist(df['gender'],bins=20)

# %%
plt.hist(df['ffr_80'],bins=20)

# %% [markdown]
# # Correlation Matrix

# %%
col = ['PID','n_frame','OS','distal','sx0','sz','ffr','ffr_80','lu','pl','luA','plA','pb','luAc','plAc','len_PB40','len_PB70']
dfdrop = df.drop(col, axis=1)

# %%
dfcorr = dfdrop.corr()
dfcorr1 = dfcorr.mask(~np.tril(np.ones(dfcorr.shape)).astype(np.bool))
dfcorr2 = dfcorr1.unstack()
dfcorr3 = dfcorr2[dfcorr2[:] != 1].sort_values(ascending=False)
dfcorr4 = dfcorr3[~np.isnan(dfcorr3)]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(15,12))
plt.rcParams.update({'font.size': 6})
sns.heatmap(dfcorr1, 
        xticklabels=dfcorr.columns,
        yticklabels=dfcorr.columns)
plt.savefig('dfcorr.pdf')
plt.show()

# %% [markdown]
# There are white lines in the matrix suggesting high correlation between all of the features. The features are No_lumen25_prox and No_lumen25_prox5. Looking at these features more closely they are all zero values. In this particular feature there are no proximal region with a lumen area less than 2.5mm2.

# %%
dfdrop = dfdrop.drop('No_lumen25_prox', axis=1)
dfdrop = dfdrop.drop('No_lumen25_prox5', axis=1)

# %%
plt.figure(figsize=(15,12))
plt.rcParams.update({'font.size': 6})
sns.heatmap(dfcorr1, 
        xticklabels=dfcorr.columns,
        yticklabels=dfcorr.columns)
plt.savefig('dfcorr.pdf')
plt.show()

# %%
print(dfcorr4.to_string())
# Out:
# No_lumen25_ROI           No_lumen25_PB40            0.999889
# No_lumen30_ROI           No_lumen30_PB40            0.999547
# PB_distal                PB_dist5                   0.999017
# max_EEM_distal           max_EEM_dist5              0.998880
# PB_prox                  PB_prox5                   0.998650
# mean_lumen_dist5         mean_EEM_dist5             0.998425
# mean_EEM_distal          mean_EEM_dist5             0.998382
# mean_lumen_prox5         mean_EEM_prox5             0.998302
# mean_lumen_distal        mean_EEM_distal            0.998296
# mean_lumen_prox          mean_EEM_prox              0.998141
# mean_plaque_distal       mean_plaque_dist5          0.997959
# mean_EEM_prox            mean_EEM_prox5             0.997876
# mean_lumen_distal        mean_lumen_dist5           0.997794
# mean_plaque_prox         mean_plaque_prox5          0.997386
# mean_lumen_prox          mean_lumen_prox5           0.997303
# mean_plaque_PB70         mean_EEM_PB70              0.997262
# mean_EEM_prox5           max_EEM_prox5              0.997014
# No_lumen40_ROI           No_lumen40_PB40            0.997009
# mean_lumen_distal        mean_EEM_dist5             0.996781
# Sum_plaque_distal        Sum_EEM_distal             0.996745
# mean_lumen_dist5         max_EEM_dist5              0.996736
# area2_stenosis_prox5     area4_stenosis_prox5       0.996678
#                          area4_stenosis_dist5       0.996678
# Sum_plaque_prox5         Sum_EEM_prox5              0.996678
# mean_EEM_dist5           max_EEM_dist5              0.996504
# mean_EEM_distal          mean_lumen_dist5           0.996414
# Sum_plaque_dist5         Sum_EEM_dist5              0.996403
# Sum_plaque_prox          Sum_EEM_prox               0.996390
# mean_lumen_prox5         max_EEM_prox5              0.996202
# mean_EEM_prox            mean_lumen_prox5           0.996100
#                          max_EEM_prox5              0.995844
# mean_lumen_prox          mean_EEM_prox5             0.995830
# max_EEM_distal           mean_lumen_dist5           0.995825
#                          mean_EEM_dist5             0.995218
# mean_plaque_dist5        mean_EEM_dist5             0.994814
# area1_stenosis_prox5     area4_stenosis_prox5       0.994748
#                          area4_stenosis_dist5       0.994748
# mean_lumen_prox          max_EEM_prox5              0.994666
# mean_plaque_distal       mean_EEM_distal            0.994443
# mean_plaque_prox5        mean_EEM_prox5             0.994420
# mean_EEM_distal          max_EEM_dist5              0.994199
# mean_lumen_distal        max_EEM_dist5              0.994132
# mean_plaque_prox         mean_EEM_prox              0.993962
# mean_EEM_distal          mean_plaque_dist5          0.993921
# area1_stenosis_prox5     area2_stenosis_prox5       0.993855
# mean_EEM_prox            max_EEM_prox               0.993432
# mean_lumen_prox          max_EEM_prox               0.993174
# mean_lumen_distal        max_EEM_distal             0.993120
# mean_EEM_distal          max_EEM_distal             0.992926
# mean_plaque_distal       mean_EEM_dist5             0.992654
# mean_EEM_prox            mean_plaque_prox5          0.992456
# mean_plaque_prox         mean_EEM_prox5             0.992196
# max_EEM_prox             max_EEM_prox5              0.991768
# mean_plaque_prox5        max_EEM_prox5              0.989854
# area2_stenosis_aver      area2_stenosis_prox5       0.989666
# mean_plaque_prox         max_EEM_prox5              0.988619
# max_EEM_prox             mean_EEM_prox5             0.988409
#                          mean_lumen_prox5           0.988405
# mean_plaque_dist5        max_EEM_dist5              0.988068
# area2_stenosis_aver      area4_stenosis_aver        0.987682
# RI_MLA_prox5             RI_worst_prox5             0.987669
# area2_stenosis_aver      area4_stenosis_prox5       0.987634
#                          area4_stenosis_dist5       0.987634
# mean_lumen_dist5         mean_plaque_dist5          0.987541
# RI_MLA_ref               RI_worst_ref               0.987375
# mean_lumen_distal        mean_plaque_dist5          0.986928
#                          mean_plaque_distal         0.986605
# mean_lumen_prox5         mean_plaque_prox5          0.986587
# max_EEM_distal           mean_plaque_dist5          0.986116
# area1_stenosis_prox5     area2_stenosis_aver        0.985945
# mean_plaque_distal       max_EEM_dist5              0.985739
# mean_lumen_prox          mean_plaque_prox           0.985427
# mean_plaque_distal       mean_lumen_dist5           0.985324
# area1_stenosis_prox5     area3_stenosis_prox5       0.985020
# area1_stenosis_dist5     area2_stenosis_dist5       0.984911
# mean_plaque_prox         mean_lumen_prox5           0.984588
#                          max_EEM_prox               0.984573
# mean_lumen_prox          mean_plaque_prox5          0.984543
# mean_plaque_distal       max_EEM_distal             0.984004
# PB_prox5                 area2_stenosis_prox5       0.983957
# PB_prox                  area2_stenosis_prox5       0.983376
# area3_stenosis_prox5     area4_stenosis_dist5       0.982315
#                          area4_stenosis_prox5       0.982315
# max_EEM_prox             mean_plaque_prox5          0.979860
# PB_distal                area2_stenosis_dist5       0.979789
# PB_dist5                 area2_stenosis_dist5       0.979649
# mean_lumen_PB70          mean_EEM_PB70              0.975706
# PB_prox5                 area4_stenosis_dist5       0.975292
#                          area4_stenosis_prox5       0.975292
# PB_prox                  area4_stenosis_dist5       0.974573
#                          area4_stenosis_prox5       0.974573
# area4_stenosis_aver      area4_stenosis_dist5       0.973921
#                          area4_stenosis_prox5       0.973921
# No_lumen40_prox          No_lumen40_prox5           0.971997
# PB_prox5                 area2_stenosis_aver        0.970596
# OS_PB40                  Sum_EEM_prox               0.970572
# PB_prox                  area2_stenosis_aver        0.969715
# area2_stenosis_prox5     area3_stenosis_prox5       0.967684
# area1_stenosis_prox5     area4_stenosis_aver        0.966822
# area3_stenosis_prox5     area4_stenosis_aver        0.965552
# area2_stenosis_prox5     area4_stenosis_aver        0.965250
# OS_PB40                  Sum_plaque_prox            0.965026
# Sum_plaque_PB70          Sum_EEM_PB70               0.963982
# area2_stenosis_aver      area3_stenosis_prox5       0.962712
# No_lumen30_prox          No_lumen30_prox5           0.960692
# PB_prox5                 area1_stenosis_prox5       0.960336
# PB_prox                  area1_stenosis_prox5       0.959942
# Sum_plaque_worst         mean_plaque_worst          0.959893
# PB_ROI                   PB_PB40                    0.957416
# No_PB70                  Sum_EEM_PB70               0.957048
# mean_lumen_PB70          mean_plaque_PB70           0.956832
# max_EEM_prox             area2_stenosis_prox5       0.956674
# area1_stenosis_dist5     area3_stenosis_dist5       0.956536
# max_EEM_prox             area4_stenosis_prox5       0.956401
#                          area4_stenosis_dist5       0.956401
# mean_EEM_prox            area4_stenosis_dist5       0.955769
#                          area4_stenosis_prox5       0.955769
#                          area2_stenosis_prox5       0.954659
# mean_EEM_prox5           area4_stenosis_prox5       0.954338
#                          area4_stenosis_dist5       0.954338
# max_EEM_prox5            area4_stenosis_dist5       0.954013
#                          area4_stenosis_prox5       0.954013
# mean_plaque_prox         area4_stenosis_dist5       0.953072
#                          area4_stenosis_prox5       0.953072
# max_EEM_prox5            area2_stenosis_prox5       0.952690
# mean_plaque_ROI          mean_plaque_PB40           0.952581
# mean_EEM_prox5           area2_stenosis_prox5       0.952312
# mean_lumen_prox          area4_stenosis_prox5       0.952285
#                          area4_stenosis_dist5       0.952285
# mean_plaque_prox         area2_stenosis_prox5       0.952187
# mean_plaque_prox5        area4_stenosis_dist5       0.951630
#                          area4_stenosis_prox5       0.951630
# max_EEM_prox             area1_stenosis_prox5       0.951360
# mean_lumen_prox5         area4_stenosis_dist5       0.951273
#                          area4_stenosis_prox5       0.951273
# mean_EEM_prox5           mean_EEM_aver              0.951219
# mean_lumen_prox          area2_stenosis_prox5       0.951055
# mean_EEM_prox            area1_stenosis_prox5       0.950886
# max_EEM_prox5            area1_stenosis_prox5       0.950487
# mean_lumen_prox5         mean_EEM_aver              0.950352
# mean_EEM_prox5           area1_stenosis_prox5       0.950155
# mean_plaque_prox5        area2_stenosis_prox5       0.949782
# mean_lumen_prox5         area2_stenosis_prox5       0.949158
# mean_EEM_prox            mean_EEM_aver              0.948819
# mean_lumen_prox          area1_stenosis_prox5       0.948815
# mean_lumen_prox5         area1_stenosis_prox5       0.948585
# max_EEM_prox5            mean_EEM_aver              0.948442
# mean_lumen_prox          mean_EEM_aver              0.947772
# max_EEM_prox             area2_stenosis_aver        0.946171
# mean_EEM_prox            area2_stenosis_aver        0.945897
# mean_EEM_prox5           area2_stenosis_aver        0.945760
# mean_plaque_prox         area1_stenosis_prox5       0.945690
# max_EEM_prox5            area2_stenosis_aver        0.945640
# mean_plaque_prox5        area1_stenosis_prox5       0.944773
#                          mean_EEM_aver              0.944558
# mean_plaque_prox         area2_stenosis_aver        0.943151
# max_EEM_prox             mean_EEM_aver              0.943120
# mean_plaque_prox5        area2_stenosis_aver        0.943094
# mean_EEM_ROI             mean_EEM_PB40              0.942997
# PB_prox                  mean_plaque_prox           0.942912
# mean_plaque_prox         PB_prox5                   0.942793
# mean_lumen_prox5         area2_stenosis_aver        0.942713
# mean_lumen_prox          area2_stenosis_aver        0.942492
# mean_plaque_prox         mean_EEM_aver              0.941799
# Sum_plaque_ROI           Sum_plaque_PB40            0.941685
# Sum_plaque_PB40          Sum_EEM_PB40               0.941554
# No_lumen25_PB70          No_lumen30_PB70            0.940701
# RI_MLA_ref               RI_MLA_prox5               0.939738
# RI_worst_ref             RI_worst_prox5             0.939633
# PB_prox5                 area4_stenosis_aver        0.939525
#                          mean_plaque_prox5          0.938992
# PB_prox                  area4_stenosis_aver        0.938339
#                          mean_plaque_prox5          0.937173
# mean_EEM_prox5           area3_stenosis_prox5       0.936889
# mean_lumen_prox5         area3_stenosis_prox5       0.936565
# max_EEM_prox5            area3_stenosis_prox5       0.936169
# mean_EEM_prox            area3_stenosis_prox5       0.935722
# max_EEM_prox             PB_prox5                   0.935400
# Sum_plaque_worst         Sum_EEM_worst              0.935273
# mean_lumen_prox          area3_stenosis_prox5       0.934941
# PB_prox                  max_EEM_prox               0.934365
# No_lumen25_PB40          No_lumen30_PB40            0.934157
# No_lumen25_ROI           No_lumen30_PB40            0.934019
# mean_EEM_prox            PB_prox5                   0.933896
# max_EEM_prox             area3_stenosis_prox5       0.933852
# No_lumen25_ROI           No_lumen30_ROI             0.933587
# No_lumen30_ROI           No_lumen25_PB40            0.933445
# RI_MLA_ref               RI_worst_prox5             0.933431
# EEM_MLA                  Sum_EEM_worst              0.933018
# mean_EEM_prox5           area4_stenosis_aver        0.932591
# PB_distal                area1_stenosis_dist5       0.932576
# PB_prox                  mean_EEM_prox              0.932382
# PB_dist5                 area1_stenosis_dist5       0.931704
# max_EEM_prox5            area4_stenosis_aver        0.931260
# EEM_MLA                  mean_EEM_worst             0.931013
# mean_EEM_prox            area4_stenosis_aver        0.930591
# mean_lumen_prox5         area4_stenosis_aver        0.929816
# PB_prox5                 mean_EEM_prox5             0.929555
# mean_plaque_prox5        area4_stenosis_aver        0.929546
#                          area3_stenosis_prox5       0.929366
# PB_prox5                 max_EEM_prox5              0.928744
# PB_prox                  mean_EEM_prox5             0.928354
# mean_plaque_prox         area3_stenosis_prox5       0.928346
# max_EEM_prox             area4_stenosis_aver        0.928156
# PB_prox                  max_EEM_prox5              0.927721
# No_lumen40_PB70          No_lumen30_PB70            0.927625
# mean_lumen_prox          area4_stenosis_aver        0.927537
# PB_MLA                   PB_worst                   0.927432
# mean_plaque_prox         area4_stenosis_aver        0.927355
# mean_EEM_aver            area4_stenosis_aver        0.927203
#                          area2_stenosis_aver        0.926207
# mean_lumen_prox          PB_prox5                   0.924086
# RI_MLA_prox5             RI_worst_ref               0.922220
# No_PB70                  No_lumen40_PB70            0.922019
# PB_prox                  mean_lumen_prox            0.921672
# No_lumen25_PB40          No_lumen25_PB70            0.919983
# PB_prox5                 mean_lumen_prox5           0.919903
# No_lumen25_ROI           No_lumen25_PB70            0.919078
# PB_prox                  mean_lumen_prox5           0.919048
# PB_prox5                 area3_stenosis_prox5       0.919026
# PB_prox                  area3_stenosis_prox5       0.918477
# Sum_EEM_worst            mean_EEM_worst             0.918139
# area2_stenosis_dist5     area3_stenosis_dist5       0.917390
# No_PB70                  Sum_plaque_PB70            0.917113
# mean_plaque_PB40         mean_EEM_PB40              0.915971
# No_lumen40_PB40          No_lumen30_PB40            0.914839
# No_lumen30_ROI           No_lumen40_PB40            0.913828
# No_lumen40_ROI           No_lumen30_ROI             0.913279
#                          No_lumen30_PB40            0.913046
# PB_prox5                 RI_worst_prox5             0.912539
# PB_prox                  RI_worst_prox5             0.911760
# MLA                      mean_lumen_worst           0.911010
# mean_plaque_worst        mean_EEM_worst             0.908501
# Sum_plaque_ROI           Sum_EEM_PB40               0.906355
# No_lumen25_distal        No_lumen30_distal          0.906276
# EEM_MLA                  mean_plaque_worst          0.902405
# mean_lumen_aver          mean_EEM_aver              0.902344
# mean_EEM_aver            area2_stenosis_prox5       0.902202
#                          area4_stenosis_dist5       0.900902
#                          area4_stenosis_prox5       0.900902
# max_EEM_dist5            area2_stenosis_dist5       0.898173
# mean_lumen_distal        area2_stenosis_dist5       0.896566
# mean_EEM_distal          area2_stenosis_dist5       0.896516
# PB_prox5                 RI_MLA_prox5               0.896364
# max_EEM_distal           area2_stenosis_dist5       0.895938
# mean_lumen_dist5         area2_stenosis_dist5       0.895712
# mean_EEM_dist5           area2_stenosis_dist5       0.895537
# Sum_EEM_worst            mean_plaque_worst          0.894894
# PB_prox                  RI_MLA_prox5               0.894804
# PB_prox5                 mean_EEM_aver              0.894747
# Sum_plaque_ROI           Sum_EEM_ROI                0.893843
# PB_prox                  mean_EEM_aver              0.892949
# max_EEM_dist5            area1_stenosis_dist5       0.889961
# mean_plaque_distal       area2_stenosis_dist5       0.888686
# max_EEM_distal           area1_stenosis_dist5       0.888216
# mean_EEM_aver            area1_stenosis_prox5       0.888143
# mean_plaque_dist5        area2_stenosis_dist5       0.888018
# mean_lumen_dist5         area1_stenosis_dist5       0.887769
# mean_lumen_distal        area1_stenosis_dist5       0.887316
# EEM_MLA                  Sum_plaque_worst           0.886609
# mean_EEM_distal          area1_stenosis_dist5       0.885701
# mean_EEM_dist5           area1_stenosis_dist5       0.885645
# mean_lumen_PB40          mean_EEM_PB40              0.880734
# No_lumen30_PB40          No_lumen30_PB70            0.879663
# PB_distal                mean_plaque_distal         0.877974
# mean_plaque_distal       PB_dist5                   0.877537
# No_lumen30_ROI           No_lumen30_PB70            0.876951
# mean_EEM_distal          PB_dist5                   0.876801
# PB_dist5                 mean_plaque_dist5          0.876657
# PB_distal                mean_EEM_distal            0.876005
#                          mean_plaque_dist5          0.875587
# area1_stenosis_aver      area3_stenosis_aver        0.875344
# mean_plaque_distal       area1_stenosis_dist5       0.875143
# mean_plaque_dist5        area1_stenosis_dist5       0.874672
# PB_prox                  RI_worst_ref               0.874592
# PB_dist5                 mean_EEM_dist5             0.874552
# PB_prox5                 RI_worst_ref               0.874519
# PB_distal                mean_EEM_dist5             0.874041
# PB_dist5                 max_EEM_dist5              0.873523
# PB_distal                max_EEM_dist5              0.873483
# area2_stenosis_prox5     RI_worst_prox5             0.872451
# mean_lumen_distal        PB_dist5                   0.872198
# mean_lumen_ROI           mean_lumen_PB40            0.871831
# PB_distal                max_EEM_distal             0.870736
#                          mean_lumen_distal          0.870722
# max_EEM_distal           PB_dist5                   0.870506
# PB_dist5                 mean_lumen_dist5           0.869512
# PB_distal                mean_lumen_dist5           0.869312
# mean_EEM_aver            area3_stenosis_prox5       0.867903
# No_lumen30_PB40          No_lumen25_PB70            0.865907
# No_lumen30_ROI           No_lumen25_PB70            0.863746
# PB_prox5                 RI_MLA_ref                 0.863629
# PB_prox                  RI_MLA_ref                 0.863253
# area1_stenosis_aver      area4_stenosis_aver        0.859724
# area2_stenosis_prox5     RI_MLA_prox5               0.858764
# No_PB40                  Sum_EEM_PB40               0.855485
# mean_EEM_ROI             mean_lumen_PB40            0.854893
# area1_stenosis_aver      area2_stenosis_aver        0.853035
# area2_stenosis_aver      RI_worst_prox5             0.852196
# max_EEM_prox             Sum_plaque_prox5           0.849043
# Sum_plaque_prox5         mean_lumen_prox5           0.848887
# mean_plaque_ROI          mean_EEM_PB40              0.848463
# Sum_EEM_prox5            mean_lumen_prox5           0.848336
# area2_stenosis_prox5     RI_worst_ref               0.848001
# mean_lumen_prox          Sum_plaque_prox5           0.847770
# area4_stenosis_dist5     RI_worst_prox5             0.847692
# area4_stenosis_prox5     RI_worst_prox5             0.847692
# max_EEM_dist5            area3_stenosis_dist5       0.847167
# mean_lumen_prox5         mean_lumen_aver            0.847072
# mean_lumen_dist5         area3_stenosis_dist5       0.846894
# mean_lumen_prox          Sum_EEM_prox5              0.846645
# max_EEM_distal           area3_stenosis_dist5       0.845954
# No_lumen25_PB40          No_lumen30_PB70            0.845192
# max_EEM_prox             Sum_EEM_prox5              0.845184
# mean_EEM_prox5           mean_lumen_aver            0.844998
# mean_lumen_distal        area3_stenosis_dist5       0.844946
# No_lumen25_ROI           No_lumen30_PB70            0.844265
# mean_lumen_prox          mean_lumen_aver            0.843605
# mean_EEM_dist5           area3_stenosis_dist5       0.843390
# mean_EEM_ROI             mean_plaque_PB40           0.843117
# max_EEM_prox5            mean_lumen_aver            0.842678
# mean_EEM_distal          area3_stenosis_dist5       0.842206
# PB_distal                area3_stenosis_dist5       0.841943
# mean_EEM_prox            mean_lumen_aver            0.841718
# area2_stenosis_aver      RI_MLA_prox5               0.841658
# Sum_EEM_ROI              Sum_EEM_PB40               0.841299
# Sum_EEM_distal           Sum_EEM_dist5              0.841118
# PB_dist5                 area3_stenosis_dist5       0.840665
# area4_stenosis_prox5     RI_MLA_prox5               0.840172
# area4_stenosis_dist5     RI_MLA_prox5               0.840172
# Sum_plaque_distal        Sum_plaque_dist5           0.838959
# Sum_plaque_worst         mean_EEM_worst             0.838874
# Sum_plaque_distal        Sum_EEM_dist5              0.838360
# area2_stenosis_prox5     RI_MLA_ref                 0.838255
# Sum_EEM_distal           Sum_plaque_dist5           0.837621
# Sum_plaque_prox5         max_EEM_prox5              0.837321
# No_PB40                  Sum_plaque_PB40            0.836815
# max_EEM_prox             mean_lumen_aver            0.836320
# area1_stenosis_aver      area1_stenosis_prox5       0.835249
# mean_plaque_prox5        mean_lumen_aver            0.833928
# Sum_EEM_prox5            max_EEM_prox5              0.833561
# mean_EEM_prox            Sum_plaque_prox5           0.833127
# Sum_plaque_prox5         mean_EEM_prox5             0.832835
# mean_lumen_ROI           mean_EEM_ROI               0.832709
# max_EEM_distal           Sum_plaque_dist5           0.830942
# mean_plaque_prox         mean_lumen_aver            0.830423
# area1_stenosis_aver      area3_stenosis_prox5       0.830335
# mean_plaque_dist5        area3_stenosis_dist5       0.830256
# mean_plaque_distal       area3_stenosis_dist5       0.829995
# Sum_EEM_prox5            mean_EEM_prox5             0.828997
# Sum_plaque_prox5         mean_EEM_aver              0.828931
# mean_EEM_prox            Sum_EEM_prox5              0.828915
# area4_stenosis_prox5     RI_worst_ref               0.827998
# area4_stenosis_dist5     RI_worst_ref               0.827998
# max_EEM_distal           Sum_EEM_dist5              0.826639
# area1_stenosis_prox5     RI_worst_prox5             0.826388
# area1_stenosis_aver      area4_stenosis_dist5       0.826017
#                          area4_stenosis_prox5       0.826017
# Sum_plaque_dist5         mean_lumen_dist5           0.825345
#                          max_EEM_dist5              0.823992
# area4_stenosis_prox5     RI_MLA_ref                 0.823878
# area4_stenosis_dist5     RI_MLA_ref                 0.823878
# Sum_EEM_prox5            mean_EEM_aver              0.823852
# mean_plaque_ROI          mean_EEM_ROI               0.823578
# Sum_EEM_dist5            mean_lumen_dist5           0.823137
# area1_stenosis_aver      area2_stenosis_prox5       0.822154
# No_lumen40_PB70          No_lumen25_PB70            0.820846
# Sum_EEM_dist5            max_EEM_dist5              0.819485
# mean_lumen_aver          area4_stenosis_aver        0.818533
# No_lumen40_PB40          No_lumen30_PB70            0.817187
# max_EEM_prox             RI_worst_prox5             0.816270
# area1_stenosis_prox5     RI_worst_ref               0.815114
#                          RI_MLA_prox5               0.814397
# mean_lumen_distal        Sum_plaque_dist5           0.814279
# No_PB70                  No_lumen30_PB70            0.812848
# mean_lumen_aver          area2_stenosis_aver        0.812561
# mean_lumen_distal        Sum_EEM_dist5              0.811591
# Sum_plaque_dist5         mean_EEM_dist5             0.809853
# No_lumen40_PB40          No_lumen40_PB70            0.808719
# No_lumen40_ROI           No_lumen30_PB70            0.808095
# area1_stenosis_prox5     RI_MLA_ref                 0.806034
# mean_EEM_prox            RI_worst_prox5             0.804039
# max_EEM_prox             RI_MLA_prox5               0.803969
# Sum_EEM_dist5            mean_EEM_dist5             0.803911
# mean_plaque_prox         RI_worst_prox5             0.803798
# Sum_plaque_prox5         area2_stenosis_prox5       0.803280
#                          area2_stenosis_aver        0.801790
#                          area1_stenosis_prox5       0.801424
#                          area4_stenosis_prox5       0.801377
#                          area4_stenosis_dist5       0.801377
# area4_stenosis_aver      RI_MLA_prox5               0.801271
# No_lumen30_ROI           No_lumen25_worst           0.800184
# No_lumen40_PB40          No_lumen25_PB40            0.800167
# No_lumen25_ROI           No_lumen40_PB40            0.800090
# mean_lumen_prox          RI_worst_prox5             0.799981
# area4_stenosis_aver      RI_worst_prox5             0.799769
# Sum_EEM_prox5            area2_stenosis_prox5       0.799638
# No_lumen30_PB40          No_lumen25_worst           0.799345
# mean_EEM_distal          Sum_plaque_dist5           0.799249
# mean_EEM_ROI             mean_EEM_worst             0.799185
# mean_plaque_prox         Sum_plaque_prox5           0.798949
# Sum_EEM_prox5            area1_stenosis_prox5       0.798599
# max_EEM_prox5            RI_worst_prox5             0.798258
# mean_EEM_aver            RI_worst_prox5             0.798176
# No_lumen40_ROI           No_lumen25_ROI             0.798003
#                          No_lumen40_PB70            0.797833
# Sum_EEM_prox5            area4_stenosis_prox5       0.797742
#                          area4_stenosis_dist5       0.797742
# No_lumen40_ROI           No_lumen25_PB40            0.797703
# Sum_EEM_prox5            area2_stenosis_aver        0.797457
# mean_lumen_ROI           mean_lumen_worst           0.797452
# Sum_plaque_prox5         mean_plaque_prox5          0.796555
# mean_EEM_prox5           RI_worst_prox5             0.795898
# mean_plaque_prox5        RI_worst_prox5             0.795879
# mean_EEM_aver            RI_MLA_prox5               0.795034
# mean_EEM_prox            RI_MLA_prox5               0.793663
# mean_EEM_prox5           area1_stenosis_aver        0.793521
# mean_lumen_prox5         area1_stenosis_aver        0.793279
# max_EEM_prox5            area1_stenosis_aver        0.793216
# mean_EEM_distal          Sum_EEM_dist5              0.793189
# mean_lumen_prox5         RI_worst_prox5             0.792105
# mean_plaque_prox         RI_MLA_prox5               0.792009
# mean_EEM_aver            area1_stenosis_aver        0.791144
# mean_lumen_prox          RI_MLA_prox5               0.790445
# No_lumen40_PB70          Sum_EEM_PB70               0.790286
# mean_EEM_prox            area1_stenosis_aver        0.790012
# mean_lumen_prox          area1_stenosis_aver        0.789512
# mean_plaque_prox         Sum_EEM_prox5              0.789219
# Sum_plaque_prox5         area4_stenosis_aver        0.788885
# max_EEM_prox5            RI_MLA_prox5               0.788712
# area2_stenosis_aver      RI_worst_ref               0.788405
# max_EEM_prox             RI_worst_ref               0.787570
#                          area1_stenosis_aver        0.787368
# mean_EEM_prox5           RI_MLA_prox5               0.787272
# mean_plaque_prox5        area1_stenosis_aver        0.787090
# Sum_plaque_prox5         area3_stenosis_prox5       0.787052
# Sum_EEM_prox5            mean_plaque_prox5          0.786796
# mean_plaque_prox5        RI_MLA_prox5               0.786172
# No_lumen30_PB40          No_lumen40_PB70            0.785313
# mean_lumen_aver          area2_stenosis_prox5       0.785222
#                          area4_stenosis_dist5       0.785147
#                          area4_stenosis_prox5       0.785147
# Sum_EEM_prox5            area3_stenosis_prox5       0.784873
#                          area4_stenosis_aver        0.784308
# mean_lumen_prox5         RI_MLA_prox5               0.784117
# mean_plaque_prox         area1_stenosis_aver        0.783498
# Sum_plaque_prox          Sum_plaque_prox5           0.782878
# No_lumen30_ROI           No_lumen40_PB70            0.782374
# PB_prox5                 area1_stenosis_aver        0.782355
# area2_stenosis_aver      RI_MLA_ref                 0.782262
# PB_prox                  area1_stenosis_aver        0.781536
# mean_EEM_PB40            mean_EEM_worst             0.781410
# mean_lumen_aver          area1_stenosis_aver        0.780135
# Sum_plaque_prox          Sum_EEM_prox5              0.780029
# mean_plaque_prox         RI_worst_ref               0.779243
# max_EEM_prox             RI_MLA_ref                 0.778570
# mean_EEM_prox            RI_worst_ref               0.776962
# No_lumen25_ROI           No_lumen25_worst           0.775308
# Sum_EEM_prox             Sum_EEM_prox5              0.775265
# Sum_plaque_dist5         mean_plaque_dist5          0.775256
# No_lumen25_PB40          No_lumen25_worst           0.774804
# mean_lumen_aver          area1_stenosis_prox5       0.774611
# Sum_EEM_prox             Sum_plaque_prox5           0.773882
# PB_prox5                 mean_lumen_aver            0.772696
# mean_plaque_prox         RI_MLA_ref                 0.771923
# mean_lumen_prox          RI_worst_ref               0.771645
# PB_prox                  mean_lumen_aver            0.771095
# MLA                      mean_lumen_ROI             0.770724
# area3_stenosis_aver      area4_stenosis_aver        0.770666
# mean_EEM_prox            RI_MLA_ref                 0.770366
# max_EEM_prox5            RI_worst_ref               0.770082
# mean_plaque_prox5        RI_worst_ref               0.770008
# mean_EEM_prox5           RI_worst_ref               0.767951
# mean_lumen_prox          RI_MLA_ref                 0.765486
# mean_plaque_distal       Sum_plaque_dist5           0.765234
# max_EEM_prox5            RI_MLA_ref                 0.765016
# mean_plaque_prox5        RI_MLA_ref                 0.764935
# mean_EEM_prox5           RI_MLA_ref                 0.763514
# mean_plaque_PB40         mean_plaque_worst          0.763489
# mean_lumen_prox5         RI_worst_ref               0.763145
# Sum_EEM_dist5            mean_plaque_dist5          0.762592
# PB_prox                  Sum_plaque_prox5           0.762545
# Sum_plaque_prox5         PB_prox5                   0.761361
# No_lumen40_PB40          No_lumen25_PB70            0.761264
# mean_lumen_aver          area3_stenosis_prox5       0.760132
# mean_lumen_prox5         RI_MLA_ref                 0.759080
# No_lumen40_PB70          Sum_plaque_PB70            0.757218
# area3_stenosis_prox5     RI_MLA_ref                 0.756275
# No_PB40                  Sum_plaque_ROI             0.755789
# area3_stenosis_prox5     RI_MLA_prox5               0.754501
# mean_plaque_PB40         mean_EEM_worst             0.754456
# No_lumen40_ROI           No_lumen25_PB70            0.754364
# PB_prox                  Sum_EEM_prox5              0.754352
# area3_stenosis_prox5     RI_worst_ref               0.753928
#                          RI_worst_prox5             0.753366
# mean_plaque_distal       Sum_EEM_dist5              0.753143
# Sum_EEM_prox5            PB_prox5                   0.752709
# No_lumen40_ROI           No_lumen25_worst           0.752523
# Sum_plaque_prox5         mean_lumen_aver            0.751270
# No_lumen40_PB40          No_lumen25_worst           0.750180
# Sum_EEM_prox5            mean_lumen_aver            0.748948
# No_lumen25_PB70          No_lumen25_worst           0.748228
# mean_plaque_ROI          mean_plaque_worst          0.745530
# Sum_EEM_ROI              Sum_plaque_PB40            0.745278
# No_lumen30_PB70          No_lumen25_worst           0.736452
# area3_stenosis_aver      area3_stenosis_prox5       0.734540
# area2_stenosis_aver      area3_stenosis_aver        0.730896
# mean_EEM_PB40            Sum_EEM_worst              0.730140
# PB_PB70                  mean_plaque_PB70           0.728883
# No_lumen25_PB40          No_lumen40_PB70            0.726936
# No_lumen25_ROI           No_lumen40_PB70            0.725983
# area4_stenosis_aver      RI_MLA_ref                 0.725113
# PB_PB70                  mean_EEM_PB70              0.724423
# mean_plaque_PB40         Sum_EEM_worst              0.723866
#                          Sum_plaque_worst           0.722008
# mean_EEM_ROI             Sum_EEM_worst              0.720890
# mean_plaque_ROI          mean_EEM_worst             0.719330
# area4_stenosis_aver      RI_worst_ref               0.718830
# EEM_MLA                  mean_EEM_ROI               0.717498
# mean_lumen_dist5         mean_lumen_aver            0.716839
# mean_lumen_PB40          mean_lumen_worst           0.715686
# mean_lumen_ROI           mean_EEM_PB40              0.715119
# max_EEM_distal           mean_lumen_aver            0.714798
# OS_PB40                  Sum_EEM_prox5              0.714565
# mean_lumen_distal        mean_lumen_aver            0.713990
# No_lumen40_distal        No_lumen40_dist5           0.713954
# mean_EEM_dist5           mean_lumen_aver            0.713831
# max_EEM_dist5            mean_lumen_aver            0.713210
# OS_PB40                  Sum_plaque_prox5           0.712555
# EEM_MLA                  mean_EEM_PB40              0.711875
# mean_EEM_distal          mean_lumen_aver            0.711444
# No_PB70                  No_lumen25_PB70            0.708818
# area1_stenosis_prox5     area3_stenosis_aver        0.707481
# area3_stenosis_aver      area4_stenosis_prox5       0.706969
#                          area4_stenosis_dist5       0.706969
# Sum_EEM_dist5            area1_stenosis_dist5       0.704834
# Sum_plaque_dist5         area1_stenosis_dist5       0.704777
# mean_plaque_dist5        mean_lumen_aver            0.702636
# EEM_MLA                  mean_plaque_PB40           0.701228
# mean_plaque_ROI          Sum_plaque_worst           0.701016
# mean_plaque_distal       mean_lumen_aver            0.700710
# Sum_plaque_prox5         RI_worst_prox5             0.699741
# Sum_EEM_prox5            RI_worst_prox5             0.698035
# mean_EEM_aver            area3_stenosis_aver        0.697272
# No_lumen40_ROI           No_lumen40_worst           0.696678
# Sum_EEM_dist5            area3_stenosis_dist5       0.695529
# Sum_plaque_dist5         area3_stenosis_dist5       0.694653
#                          area2_stenosis_dist5       0.693723
# OS_MLA                   long_eccentricity_PB40     0.693347
# Sum_EEM_dist5            area2_stenosis_dist5       0.692298
# No_lumen40_PB40          No_lumen40_worst           0.691939
# MLA                      mean_lumen_PB40            0.691056
# Sum_plaque_prox5         RI_MLA_prox5               0.690639
# No_PB70                  No_lumen40_PB40            0.689917
# Sum_EEM_prox5            RI_MLA_prox5               0.689714
# mean_lumen_aver          RI_worst_prox5             0.688775
# area2_stenosis_prox5     area3_stenosis_aver        0.688630
# mean_lumen_aver          RI_MLA_prox5               0.688433
# PB_PB70                  mean_lumen_PB70            0.687737
# mean_lumen_prox5         area3_stenosis_aver        0.681952
# mean_EEM_aver            RI_MLA_ref                 0.681528
# mean_EEM_prox5           area3_stenosis_aver        0.680715
# mean_plaque_ROI          Sum_EEM_worst              0.680212
# mean_EEM_aver            RI_worst_ref               0.680098
# max_EEM_prox5            area3_stenosis_aver        0.679287
# Sum_plaque_prox5         area1_stenosis_aver        0.678474
# No_PB70                  No_lumen40_ROI             0.678342
# mean_lumen_prox          area3_stenosis_aver        0.676344
# Sum_EEM_prox5            area1_stenosis_aver        0.675288
# mean_EEM_prox            area3_stenosis_aver        0.675237
# mean_plaque_prox5        area3_stenosis_aver        0.672583
# mean_EEM_PB40            mean_plaque_worst          0.670491
# max_EEM_prox             area3_stenosis_aver        0.670323
# mean_plaque_prox         area3_stenosis_aver        0.666906
# No_PB70                  No_lumen30_PB40            0.663669
#                          No_lumen30_ROI             0.660867
# EEM_MLA                  mean_plaque_ROI            0.659347
# PB_PB40                  PB_PB70                    0.656143
# PB_MLA                   Sum_plaque_worst           0.654661
# Sum_plaque_prox          max_EEM_prox               0.653006
# area1_stenosis_aver      RI_worst_prox5             0.651024
# PB_ROI                   PB_PB70                    0.650020
# No_lumen40_PB70          No_lumen25_worst           0.648860
# mean_EEM_ROI             mean_lumen_worst           0.648719
# Sum_plaque_prox5         RI_worst_ref               0.647959
# Sum_plaque_distal        max_EEM_distal             0.647741
# Sum_EEM_prox             max_EEM_prox               0.647461
# Sum_EEM_prox5            RI_worst_ref               0.647130
# Sum_EEM_distal           max_EEM_distal             0.646330
# No_lumen30_PB70          Sum_EEM_PB70               0.646115
# area1_stenosis_aver      RI_MLA_prox5               0.645946
# mean_EEM_ROI             mean_plaque_worst          0.643503
# PB_prox5                 area3_stenosis_aver        0.642668
# mean_lumen_PB40          mean_EEM_worst             0.642525
# Sum_plaque_PB40          Sum_plaque_PB70            0.642342
# PB_distal                Sum_plaque_dist5           0.642214
# No_lumen40_worst         No_lumen25_worst           0.641873
# Sum_plaque_prox5         RI_MLA_ref                 0.641844
# Sum_plaque_worst         PB_worst                   0.641826
# PB_prox                  area3_stenosis_aver        0.641603
# Sum_EEM_prox5            RI_MLA_ref                 0.641594
# Sum_plaque_dist5         PB_dist5                   0.641432
# No_lumen40_distal        No_lumen30_distal          0.638811
# Sum_EEM_distal           mean_lumen_dist5           0.637163
# Sum_plaque_distal        mean_lumen_dist5           0.636661
# PB_distal                Sum_EEM_dist5              0.636039
# Sum_EEM_dist5            PB_dist5                   0.634671
# No_PB40                  Sum_EEM_ROI                0.632985
# Sum_plaque_distal        max_EEM_dist5              0.631333
# Sum_EEM_distal           max_EEM_dist5              0.629926
# mean_lumen_aver          area2_stenosis_dist5       0.629455
# Sum_plaque_prox          mean_lumen_prox            0.628593
# Sum_plaque_PB40          Sum_EEM_PB70               0.628034
# Sum_EEM_prox             mean_lumen_prox            0.626018
# PB_MLA                   mean_plaque_PB70           0.625179
# mean_EEM_PB40            Sum_plaque_worst           0.624404
# No_lumen30_PB70          Sum_plaque_PB70            0.623584
# Sum_plaque_distal        mean_EEM_dist5             0.622497
# Sum_EEM_distal           mean_EEM_dist5             0.620949
# No_PB70                  No_lumen25_PB40            0.618124
# PB_PB70                  PB_worst                   0.617770
# No_PB70                  PB_worst                   0.617325
# mean_lumen_worst         mean_EEM_worst             0.617232
# mean_lumen_aver          area1_stenosis_dist5       0.617189
# No_PB70                  No_lumen25_ROI             0.617157
# PB_distal                mean_lumen_aver            0.616854
# mean_lumen_PB40          mean_plaque_PB40           0.616693
# mean_plaque_PB70         PB_worst                   0.616160
# PB_dist5                 mean_lumen_aver            0.615824
# Sum_EEM_distal           mean_lumen_distal          0.615706
# Sum_plaque_prox          mean_EEM_prox              0.615511
# Sum_plaque_dist5         mean_lumen_aver            0.615336
# Sum_EEM_dist5            mean_lumen_aver            0.615333
# mean_plaque_ROI          Sum_EEM_PB40               0.614068
#                          Sum_plaque_PB40            0.613862
# Sum_plaque_distal        mean_lumen_distal          0.613623
# Sum_plaque_prox          area2_stenosis_prox5       0.612949
#                          mean_EEM_aver              0.612827
# Sum_EEM_PB70             PB_worst                   0.610813
# Sum_EEM_prox             mean_EEM_prox              0.609850
# Sum_plaque_prox          mean_lumen_prox5           0.609285
#                          area2_stenosis_aver        0.607746
# Sum_EEM_prox             area2_stenosis_prox5       0.607582
# PB_MLA                   PB_PB70                    0.607408
# Sum_EEM_prox             mean_EEM_aver              0.606164
# mean_lumen_ROI           mean_EEM_worst             0.605803
# Sum_EEM_prox             mean_lumen_prox5           0.605173
# OS_PB40                  max_EEM_prox               0.602999
# Sum_plaque_prox          area4_stenosis_prox5       0.602760
#                          area4_stenosis_dist5       0.602760
# MLA                      mean_EEM_ROI               0.602566
# Sum_plaque_distal        mean_EEM_distal            0.602249
# PB_worst                 mean_plaque_worst          0.602080
# Sum_plaque_prox          area1_stenosis_prox5       0.601825
# Sum_EEM_prox             area2_stenosis_aver        0.601756
# Sum_EEM_distal           mean_EEM_distal            0.601197
# Sum_plaque_prox          max_EEM_prox5              0.599827
# mean_plaque_PB70         mean_plaque_worst          0.599148
# PB_MLA                   mean_EEM_PB70              0.599027
#                          mean_plaque_worst          0.598464
# OS_PB40                  area2_stenosis_prox5       0.597536
# Sum_EEM_prox             area4_stenosis_prox5       0.597521
#                          area4_stenosis_dist5       0.597521
# mean_plaque_PB70         Sum_plaque_worst           0.597189
# Sum_EEM_prox             area1_stenosis_prox5       0.596865
# Sum_plaque_prox          mean_EEM_prox5             0.596117
# Sum_EEM_prox             max_EEM_prox5              0.593737
# mean_plaque_ROI          mean_plaque_PB70           0.592130
# Sum_plaque_prox          PB_prox5                   0.591843
# Sum_plaque_distal        mean_plaque_dist5          0.591815
# Sum_plaque_prox          PB_prox                    0.591244
# Sum_EEM_prox             mean_EEM_prox5             0.590137
# mean_EEM_ROI             Sum_plaque_worst           0.588570
# OS_PB40                  area2_stenosis_aver        0.587972
# Sum_EEM_distal           mean_plaque_dist5          0.586563
# Sum_plaque_prox          mean_plaque_prox           0.586185
# mean_EEM_PB70            PB_worst                   0.585857
# OS_PB40                  area4_stenosis_prox5       0.585270
#                          area4_stenosis_dist5       0.585270
# Sum_plaque_prox5         area3_stenosis_aver        0.585028
# Sum_EEM_prox             PB_prox5                   0.583765
# mean_plaque_ROI          mean_EEM_PB70              0.582956
# mean_lumen_aver          area3_stenosis_dist5       0.582719
# Sum_plaque_prox          area4_stenosis_aver        0.582642
# Sum_EEM_prox5            area3_stenosis_aver        0.582585
# OS_PB40                  area1_stenosis_prox5       0.581638
# Sum_EEM_prox             PB_prox                    0.580753
# OS_PB40                  PB_prox5                   0.580359
#                          RI_worst_prox5             0.579574
# mean_plaque_PB40         mean_plaque_PB70           0.579070
# mean_lumen_PB40          Sum_EEM_worst              0.578047
# OS_PB40                  PB_prox                    0.577551
# mean_EEM_PB70            mean_plaque_worst          0.576782
# Sum_EEM_prox             area4_stenosis_aver        0.576534
# Sum_plaque_distal        mean_plaque_distal         0.576531
# mean_EEM_PB70            Sum_plaque_worst           0.575618
# mean_lumen_aver          area3_stenosis_aver        0.575204
# Sum_EEM_prox             mean_plaque_prox           0.575021
# mean_lumen_aver          RI_MLA_ref                 0.574122
# Sum_plaque_prox          area3_stenosis_prox5       0.573752
# area1_stenosis_aver      RI_worst_ref               0.573276
# No_lumen40_PB70          PB_worst                   0.572380
# OS_PB40                  mean_lumen_prox            0.572237
# area1_stenosis_aver      RI_MLA_ref                 0.571475
# mean_plaque_PB40         mean_EEM_PB70              0.571319
# mean_lumen_aver          RI_worst_ref               0.570634
# Sum_plaque_ROI           mean_plaque_ROI            0.570121
# Sum_EEM_distal           mean_plaque_distal         0.569830
# Sum_EEM_prox             area3_stenosis_prox5       0.569480
# EEM_MLA                  mean_lumen_PB40            0.568932
# Sum_plaque_prox          mean_plaque_prox5          0.567108
# PB_ROI                   Sum_plaque_PB70            0.566294
# Sum_plaque_PB70          PB_worst                   0.565235
# Sum_plaque_prox          RI_worst_prox5             0.564099
# Sum_plaque_ROI           Sum_plaque_PB70            0.563322
# No_PB70                  Sum_plaque_PB40            0.560970
# Sum_EEM_prox             RI_worst_prox5             0.560916
# No_lumen40_PB70          No_lumen40_worst           0.560863
# OS_PB40                  RI_MLA_prox5               0.559849
# OS_MLA                   No_PB40                    0.559169
# No_lumen30_ROI           No_lumen40_worst           0.558955
# OS_PB40                  area4_stenosis_aver        0.558551
# No_lumen30_PB40          No_lumen40_worst           0.558160
# Sum_EEM_prox             mean_plaque_prox5          0.557797
# OS_MLA                   Sum_EEM_ROI                0.557454
# mean_EEM_PB40            mean_lumen_worst           0.556531
# OS_PB40                  mean_EEM_prox              0.556515
# Sum_plaque_PB70          PB_PB70                    0.553731
# OS_PB40                  mean_EEM_aver              0.552017
# Sum_plaque_prox          mean_lumen_aver            0.551853
# PB_ROI                   Sum_plaque_PB40            0.551765
# OS_PB40                  area3_stenosis_prox5       0.549811
# MLA                      mean_EEM_worst             0.549748
# OS_PB40                  mean_lumen_prox5           0.547527
# No_PB70                  No_lumen25_worst           0.547272
# Sum_EEM_prox             mean_lumen_aver            0.547201
# Sum_plaque_prox          RI_MLA_prox5               0.544644
# Sum_plaque_ROI           Sum_EEM_PB70               0.544535
# PB_PB40                  Sum_plaque_PB70            0.543569
# No_PB40                  No_PB70                    0.542567
# Sum_EEM_prox             RI_MLA_prox5               0.542214
# mean_plaque_ROI          mean_lumen_PB40            0.540219
# OS_PB40                  max_EEM_prox5              0.538217
# mean_plaque_ROI          mean_lumen_PB70            0.536886
# No_lumen40_worst         PB_worst                   0.536154
# PB_MLA                   Sum_EEM_PB70               0.534449
# No_lumen25_PB70          Sum_EEM_PB70               0.534341
# PB_MLA                   No_PB70                    0.533479
# OS_PB40                  mean_EEM_prox5             0.533002
# Sum_EEM_ROI              mean_EEM_ROI               0.530718
# EEM_MLA                  mean_lumen_ROI             0.530663
# mean_plaque_PB40         mean_lumen_PB70            0.529842
# No_lumen40_distal        No_lumen25_distal          0.529823
# Sum_EEM_PB70             mean_plaque_PB70           0.529524
# No_lumen40_PB40          Sum_EEM_PB70               0.528452
# Sum_EEM_PB40             mean_plaque_PB40           0.527153
# OS_PB40                  RI_worst_ref               0.526582
# Sum_EEM_ROI              mean_EEM_PB40              0.524403
# OS_PB40                  mean_plaque_prox           0.522991
# No_PB40                  No_lumen40_PB40            0.520919
# No_lumen40_ROI           Sum_EEM_PB70               0.517527
# MLA                      mean_EEM_PB40              0.517478
# No_PB70                  PB_PB70                    0.516742
# Sum_plaque_ROI           mean_plaque_PB40           0.515888
# mean_lumen_ROI           Sum_EEM_worst              0.515845
# Sum_plaque_PB40          mean_plaque_PB40           0.515501
# No_lumen30_PB70          No_lumen40_worst           0.514800
# No_lumen25_PB70          Sum_plaque_PB70            0.514529
# No_PB40                  No_lumen40_ROI             0.513959
# area3_stenosis_aver      RI_MLA_prox5               0.513864
# Sum_plaque_PB40          PB_PB40                    0.513307
# Sum_plaque_prox          RI_worst_ref               0.512643
# No_PB40                  Sum_EEM_PB70               0.512168
# Sum_EEM_PB70             PB_PB70                    0.511989
# Sum_EEM_distal           area3_stenosis_dist5       0.511588
# No_PB70                  PB_ROI                     0.511287
# Sum_plaque_distal        area3_stenosis_dist5       0.510935
# Sum_EEM_prox             RI_worst_ref               0.510081
# Sum_EEM_distal           area1_stenosis_dist5       0.509993
# Sum_plaque_distal        area1_stenosis_dist5       0.509352
# No_lumen40_PB40          Sum_plaque_PB70            0.505851
# PB_ROI                   Sum_EEM_PB70               0.503673
# Sum_plaque_distal        mean_lumen_aver            0.503516
# Sum_EEM_distal           mean_lumen_aver            0.502994
# OS_PB40                  RI_MLA_ref                 0.502588
# PB_MLA                   mean_lumen_PB70            0.502142
# ...
# No_lumen40_PB70          mean_lumen_dist5          -0.255425
# No_lumen30_PB40          mean_plaque_distal        -0.255481
# PB_PB40                  Sum_plaque_dist5          -0.255493
# No_PB40                  Sum_plaque_distal         -0.255700
# No_lumen30_ROI           mean_plaque_distal        -0.255727
# PB_PB70                  max_EEM_distal            -0.256438
# No_lumen30_PB40          mean_plaque_dist5         -0.256695
# No_lumen30_ROI           mean_plaque_dist5         -0.256762
# PB_PB70                  max_EEM_dist5             -0.256985
# No_lumen40_ROI           variance_lumen_worst      -0.257210
# mean_lumen_PB40          Sum_EEM_PB70              -0.257527
# PB_PB70                  mean_EEM_distal           -0.257838
# No_lumen25_worst         mean_plaque_distal        -0.258126
#                          mean_plaque_dist5         -0.259304
# PB_PB70                  mean_EEM_dist5            -0.259711
# No_lumen30_ROI           max_EEM_dist5             -0.259769
# No_lumen30_PB40          max_EEM_dist5             -0.259871
# PB_PB40                  Sum_EEM_dist5             -0.260044
# No_lumen30_PB40          mean_EEM_distal           -0.260390
# No_lumen30_ROI           max_EEM_distal            -0.260424
#                          mean_EEM_distal           -0.260551
# No_lumen30_PB40          max_EEM_distal            -0.260560
# No_lumen30_ROI           mean_EEM_dist5            -0.260904
# No_lumen30_PB40          mean_EEM_dist5            -0.260950
# PB_ROI                   Sum_plaque_distal         -0.261039
# Sum_EEM_PB70             mean_lumen_aver           -0.261124
# PB_PB70                  mean_lumen_distal         -0.261635
# No_lumen30_PB40          mean_lumen_distal         -0.261865
# No_lumen30_ROI           mean_lumen_distal         -0.261979
#                          mean_lumen_dist5          -0.262031
# PB_PB70                  mean_lumen_dist5          -0.262097
# No_lumen30_PB40          mean_lumen_dist5          -0.262140
# OS_MLA                   mean_lumen_worst          -0.262654
# No_lumen25_worst         max_EEM_dist5             -0.263158
#                          mean_EEM_distal           -0.263286
#                          mean_EEM_dist5            -0.263743
#                          max_EEM_distal            -0.263978
# No_PB40                  mean_EEM_distal           -0.264117
# Sum_plaque_PB70          mean_lumen_aver           -0.264182
# No_PB40                  Sum_EEM_distal            -0.264379
# No_lumen25_worst         mean_lumen_distal         -0.264887
#                          mean_lumen_dist5          -0.265021
# gender                   mean_plaque_ROI           -0.265318
# mean_EEM_ROI             No_lumen40_PB70           -0.266315
# No_PB40                  mean_EEM_dist5            -0.266526
# No_lumen30_ROI           mean_lumen_aver           -0.266614
# No_lumen25_PB40          Sum_EEM_worst             -0.266942
# No_lumen30_PB40          mean_lumen_aver           -0.267582
# No_lumen25_ROI           Sum_EEM_worst             -0.267984
# PB_ROI                   Sum_EEM_distal            -0.268037
# MLA                      mean_plaque_PB70          -0.268434
# PB_PB40                  mean_plaque_distal        -0.269326
# MLA                      long_eccentricity_PB40    -0.271029
# PB_PB70                  PB_distal                 -0.271585
# No_PB40                  mean_lumen_distal         -0.272145
#                          mean_lumen_dist5          -0.273045
# OS_MLA                   Sum_plaque_worst          -0.273211
# No_PB40                  max_EEM_dist5             -0.273307
# EEM_MLA                  No_lumen25_PB40           -0.273512
# PB_PB70                  PB_dist5                  -0.273780
# EEM_MLA                  No_lumen25_ROI            -0.274698
# mean_plaque_worst        long_eccentricity_PB40    -0.274930
# PB_PB40                  mean_plaque_dist5         -0.275192
# No_PB40                  max_EEM_distal            -0.275521
# PB_PB40                  mean_lumen_aver           -0.276219
# Sum_plaque_worst         long_eccentricity_PB40    -0.276312
# PB_PB40                  mean_lumen_PB40           -0.276612
# No_PB40                  mean_lumen_aver           -0.277738
# vessel                   No_lumen40_worst          -0.280381
# PB_PB40                  mean_EEM_distal           -0.281091
# No_lumen40_ROI           Sum_EEM_dist5             -0.282164
#                          Sum_plaque_dist5          -0.283047
# No_lumen40_PB40          mean_plaque_PB40          -0.284323
# PB_PB40                  mean_EEM_dist5            -0.285441
# No_lumen40_PB40          Sum_EEM_dist5             -0.285641
# PB_PB40                  mean_lumen_distal         -0.286268
# No_lumen40_PB40          Sum_plaque_dist5          -0.286286
# PB_PB40                  area2_stenosis_dist5      -0.286622
# No_lumen40_PB70          mean_lumen_aver           -0.287425
# PB_ROI                   area1_stenosis_dist5      -0.287730
# mean_EEM_PB40            No_lumen25_PB70           -0.289513
# No_PB70                  mean_lumen_aver           -0.289609
# PB_PB40                  mean_lumen_dist5          -0.289828
# PB_MLA                   mean_lumen_ROI            -0.289941
# PB_PB40                  max_EEM_dist5             -0.290280
#                          max_EEM_distal            -0.290702
# mean_EEM_PB40            No_lumen30_PB70           -0.292600
# No_lumen25_worst         Sum_EEM_worst             -0.292607
# No_lumen40_worst         mean_lumen_aver           -0.293164
# PB_ROI                   mean_lumen_PB40           -0.296085
# No_lumen40_ROI           mean_plaque_PB40          -0.296896
# No_lumen40_worst         Sum_EEM_dist5             -0.297970
# No_PB40                  Sum_plaque_dist5          -0.299068
# No_lumen40_worst         Sum_plaque_dist5          -0.299534
# OS_MLA                   mean_plaque_worst         -0.300416
# EEM_MLA                  No_lumen25_worst          -0.302836
# No_PB40                  Sum_EEM_dist5             -0.304394
# No_lumen40_ROI           mean_plaque_distal        -0.305648
#                          mean_plaque_dist5         -0.307558
# No_lumen40_PB40          mean_plaque_distal        -0.307634
# mean_lumen_ROI           PB_PB70                   -0.308440
# PB_PB40                  PB_distal                 -0.309099
# No_lumen40_PB40          mean_plaque_dist5         -0.309826
# PB_PB40                  PB_dist5                  -0.310374
# No_lumen40_ROI           mean_EEM_distal           -0.310621
#                          max_EEM_dist5             -0.310805
#                          max_EEM_distal            -0.311559
#                          mean_EEM_dist5            -0.311619
#                          mean_lumen_distal         -0.311892
# No_lumen40_worst         variance_lumen_worst      -0.312337
# No_lumen40_ROI           mean_lumen_dist5          -0.312477
# PB_ROI                   mean_plaque_distal        -0.312699
# No_lumen40_PB40          mean_EEM_distal           -0.313011
# PB_ROI                   Sum_plaque_dist5          -0.313188
# No_lumen40_PB40          max_EEM_dist5             -0.313805
#                          mean_EEM_dist5            -0.314343
#                          mean_lumen_distal         -0.314494
#                          max_EEM_distal            -0.314547
# No_lumen25_PB40          mean_EEM_worst            -0.314778
# No_lumen40_PB40          mean_lumen_dist5          -0.315439
# OS_MLA                   Sum_EEM_worst             -0.315884
# No_lumen25_ROI           mean_EEM_worst            -0.315906
# No_lumen40_worst         mean_plaque_distal        -0.316194
# No_lumen40_ROI           mean_lumen_aver           -0.316539
# mean_EEM_ROI             No_lumen25_PB70           -0.316755
# PB_ROI                   Sum_EEM_dist5             -0.317853
# mean_plaque_PB40         No_lumen40_worst          -0.318551
# No_lumen40_worst         mean_plaque_dist5         -0.318824
# PB_ROI                   mean_plaque_dist5         -0.319029
# No_lumen40_worst         max_EEM_dist5             -0.319338
#                          max_EEM_distal            -0.320191
# PB_ROI                   area2_stenosis_dist5      -0.320443
# No_lumen40_worst         mean_EEM_distal           -0.321034
# OS_PB70                  MLA                       -0.321148
# No_lumen40_PB40          mean_lumen_aver           -0.321387
# mean_lumen_ROI           Sum_plaque_PB70           -0.322179
# No_lumen40_worst         mean_lumen_distal         -0.322180
# No_lumen30_PB40          Sum_EEM_worst             -0.322460
# No_lumen40_worst         mean_EEM_dist5            -0.322699
#                          mean_lumen_dist5          -0.323405
# mean_EEM_worst           long_eccentricity_PB40    -0.324156
# No_lumen30_ROI           Sum_EEM_worst             -0.324819
# Sum_EEM_worst            long_eccentricity_PB40    -0.324901
# mean_EEM_ROI             No_lumen30_PB70           -0.325370
# PB_ROI                   mean_EEM_distal           -0.327007
#                          mean_EEM_dist5            -0.331314
# EEM_MLA                  No_lumen30_PB40           -0.333018
# PB_ROI                   mean_lumen_distal         -0.333374
# OS_PB70                  mean_lumen_worst          -0.333992
# PB_ROI                   PB_distal                 -0.335455
# EEM_MLA                  No_lumen30_ROI            -0.335657
# PB_ROI                   max_EEM_dist5             -0.335882
#                          mean_lumen_dist5          -0.336620
#                          PB_dist5                  -0.337137
#                          max_EEM_distal            -0.337499
# No_PB40                  mean_lumen_ROI            -0.338409
# mean_lumen_ROI           Sum_EEM_PB70              -0.341407
# OS_MLA                   EEM_MLA                   -0.342464
# PB_ROI                   mean_lumen_aver           -0.343637
# Sum_plaque_PB70          mean_lumen_worst          -0.350890
# OS_MLA                   mean_EEM_worst            -0.355827
# No_lumen25_PB40          mean_EEM_PB40             -0.356279
# No_lumen25_ROI           mean_EEM_PB40             -0.356972
# EEM_MLA                  long_eccentricity_PB40    -0.358191
# PB_PB40                  mean_lumen_worst          -0.358435
# MLA                      Sum_plaque_PB70           -0.361026
# PB_ROI                   mean_lumen_worst          -0.362726
# mean_lumen_ROI           PB_worst                  -0.370075
# No_lumen25_worst         mean_EEM_worst            -0.373712
# No_lumen40_PB40          Sum_EEM_worst             -0.374443
# No_lumen40_worst         Sum_EEM_worst             -0.377738
# No_PB70                  mean_lumen_PB40           -0.378737
# Sum_EEM_PB70             mean_lumen_worst          -0.379728
# No_lumen30_PB40          mean_EEM_worst            -0.381869
# mean_EEM_ROI             No_lumen25_PB40           -0.383114
# No_lumen25_ROI           mean_EEM_ROI              -0.383803
# mean_lumen_ROI           PB_PB40                   -0.384094
# No_lumen30_ROI           mean_EEM_worst            -0.384418
# No_lumen40_ROI           Sum_EEM_worst             -0.385769
# MLA                      Sum_EEM_PB70              -0.389696
# EEM_MLA                  No_lumen40_PB40           -0.391208
# MLA                      PB_PB40                   -0.392538
#                          PB_ROI                    -0.393343
# Sum_plaque_PB40          long_eccentricity_worst   -0.398101
# EEM_MLA                  No_lumen40_ROI            -0.403633
# OS_MLA                   long_eccentricity_worst   -0.406676
# mean_EEM_PB40            No_lumen25_worst          -0.408659
# PB_PB70                  mean_lumen_worst          -0.410622
# EEM_MLA                  No_lumen40_worst          -0.411340
# MLA                      No_PB40                   -0.412303
# No_PB40                  mean_lumen_worst          -0.420134
# PB_ROI                   mean_lumen_ROI            -0.427824
# No_lumen30_PB40          mean_EEM_PB40             -0.431425
# No_lumen30_ROI           mean_EEM_PB40             -0.433274
# MLA                      No_lumen25_PB70           -0.434014
# Sum_EEM_PB40             long_eccentricity_worst   -0.440055
# mean_EEM_ROI             No_lumen25_worst          -0.440453
# MLA                      No_lumen25_PB40           -0.441045
#                          No_lumen25_ROI            -0.441438
# mean_lumen_PB40          No_lumen25_PB70           -0.444573
# No_lumen40_PB40          mean_EEM_worst            -0.450538
# No_PB70                  mean_lumen_ROI            -0.450940
# No_lumen25_PB70          mean_lumen_worst          -0.451169
# mean_lumen_ROI           No_lumen25_PB70           -0.461613
# mean_EEM_ROI             No_lumen30_PB40           -0.462574
# No_lumen40_ROI           mean_EEM_worst            -0.462886
# No_lumen25_PB40          mean_lumen_worst          -0.463108
# No_lumen25_ROI           mean_lumen_worst          -0.463470
# No_lumen30_ROI           mean_EEM_ROI              -0.464391
# Sum_plaque_ROI           long_eccentricity_worst   -0.465260
# No_PB70                  mean_lumen_worst          -0.470022
# MLA                      No_PB70                   -0.471296
# No_lumen25_PB40          mean_lumen_PB40           -0.474033
# No_lumen25_ROI           mean_lumen_PB40           -0.474328
# PB_MLA                   mean_lumen_worst          -0.475122
# MLA                      PB_PB70                   -0.477530
# mean_lumen_PB40          No_lumen40_PB70           -0.485616
# mean_lumen_ROI           No_lumen25_PB40           -0.487585
# No_lumen25_ROI           mean_lumen_ROI            -0.487769
# mean_lumen_PB40          No_lumen30_PB70           -0.491919
# MLA                      No_lumen30_PB70           -0.492744
# Sum_EEM_ROI              long_eccentricity_worst   -0.503223
# No_lumen30_PB70          mean_lumen_worst          -0.507453
# No_lumen40_PB40          mean_EEM_PB40             -0.507989
# mean_lumen_ROI           No_lumen30_PB70           -0.516764
# No_lumen40_ROI           mean_EEM_PB40             -0.517966
# MLA                      No_lumen40_PB70           -0.519901
#                          PB_MLA                    -0.522792
# No_lumen40_worst         mean_EEM_worst            -0.526845
# MLA                      No_lumen30_PB40           -0.527274
#                          No_lumen30_ROI            -0.527879
# mean_lumen_ROI           No_lumen40_PB70           -0.529472
# No_lumen40_PB70          mean_lumen_worst          -0.530255
# No_PB40                  long_eccentricity_worst   -0.530391
# mean_lumen_PB40          No_lumen25_worst          -0.532596
# mean_EEM_PB40            No_lumen40_worst          -0.532884
# MLA                      PB_worst                  -0.539227
# mean_EEM_ROI             No_lumen40_PB40           -0.549089
# mean_lumen_ROI           No_lumen25_worst          -0.551327
# No_lumen30_PB40          mean_lumen_worst          -0.552061
# No_lumen30_ROI           mean_lumen_worst          -0.552712
# No_lumen40_ROI           mean_EEM_ROI              -0.560100
# PB_worst                 mean_lumen_worst          -0.566012
# No_lumen30_PB40          mean_lumen_PB40           -0.566178
# No_lumen30_ROI           mean_lumen_PB40           -0.566916
# mean_EEM_ROI             No_lumen40_worst          -0.579594
# mean_lumen_ROI           No_lumen30_PB40           -0.581658
# No_lumen30_ROI           mean_lumen_ROI            -0.581992
# MLA                      No_lumen25_worst          -0.582155
# No_lumen25_worst         mean_lumen_worst          -0.612179
# MLA                      No_lumen40_PB40           -0.612861
#                          No_lumen40_ROI            -0.615378
# No_lumen40_PB40          mean_lumen_worst          -0.643372
# No_lumen40_ROI           mean_lumen_worst          -0.646661
# No_lumen40_PB40          mean_lumen_PB40           -0.661024
# No_lumen40_ROI           mean_lumen_PB40           -0.665756
# mean_lumen_PB40          No_lumen40_worst          -0.669464
# mean_lumen_ROI           No_lumen40_PB40           -0.689206
# No_lumen40_ROI           mean_lumen_ROI            -0.692553
# mean_lumen_ROI           No_lumen40_worst          -0.702223
# MLA                      No_lumen40_worst          -0.786894
# No_lumen40_worst         mean_lumen_worst          -0.834666

# %% [markdown]
# # PCA Component Analysis

# %%
dfdrop.shape

# %%
dfdrop.head()

# %%
print(df.isnull().sum().to_string())
### investigate null values

# %%
dfdrdf.dropna()

# %%
from sklearn.decomposition import PCA

nf = 111
pca = PCA(n_components=nf)
# X is the matrix transposed (n samples on the rows, m features on the columns)
pca.fit_transform(dfdrop)

dfpca = pca.transform(dfdrop)
dfpca

# %%
x = np.array([
        [0.387,4878, 5.42, 5.42],
        [0.723,12104,5.25, 5.42],
        [1,12756,5.52, 5.42],
        [1.524,6787,3.94, 5.42],
    ])


pca = PCA(n_components=3)
pca.fit_transform(x)
dfpca = pca.transform(x)
dfpca

# %%
df.iloc[1]

# %%
i=42
distal = df.iloc[i]['distal']
os = df.iloc[i]['OS']
luAc = df.iloc[i]['luAc']
plAc = df.iloc[i]['plAc']
pbth = 0.4
th = 4.0
gap = 300

# %%
no_lumen40_prox5(luAc,plAc,distal,os,pbth,th,gap)

# %%
lesion(luAc,plAc,distal,os,pbth,gap) == -1

# %%
len(df)

# %%
test = [6,7,4,8,1,5,8,3]
np.argmin(test)

# %%
test = [1,2,3]
test[-1]
